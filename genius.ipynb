# %% [markdown]
# # GENIUS GAME
#
# ##SUBTITLES
#
# ### '#N°' - MAINS TOPICS (TESTS)
# ### '##' - CODE TESTED IN STAND BY
# ### 'TAB##' - COMENTS

# %%
import random

# %% [markdown]
# # 1: tests to figure out how to create random numbers
#
# ##random.randint(0, 10)
#     ## seems to work
#
# # 2: tests to realize how to creat a list with random numbers
#
# ##random_numbs = []
# ##for random in range(10):
#     ##random_numbs.append(random.randint)
#
# # 3: verifying random functions characters (shift tab)
#
# ##random.randint()
#     ##it seems to be missing informatios so that the shift tab can return infos.

# %% [markdown]
# # 4: checking out if we can use a list of range as reference to a random list:
#
# ##print(range(10))
# ##range(10)
# ##range_ten_list = []
# ##for i in range(10):
#     ##range_ten_list.append(i)
# #print(range_ten_list)
#
#     ##ok! the list is made. let´s see if we can randomize the numbs inside the list to generate a new list

# %% [markdown]
# # 5: tests to see if we can create a radom list from the range_ten_list
#
# ##random_list = []
# ##for numbs in range_ten_list:
#     ##random_list.append(random.randint(range_ten_list, 5))
# ##print(random_list)
#     ##it seems confused

# %% [markdown]
# # 6: let´s try to directly create a random list. I mean, with no need of a previous random range ten list.
#
# ##random_list_six = []
# ##for i in range(5):
#     ##random_list_six.append(random.randint(0, 10))
# ##print(random_list_six)
#
#     ##it has worked perfectly

# %% [markdown]
# # 7: let´s try to add an input
#
# ##random_list_seven = []
# ##a = [1]
#     ## let´s try to use 'a' to rise one unit each time the user gets right
# ##randoms = [range(10)]
#     ## the idea here is to use 'randoms' to generates ramdom lists within random number from 0 to 10
# ##for i in range(len(a)):
#     ## a=1 in the first round
#     ##random_list_seven.append(random.randint(0, 10))
#     ##print('it´s your time', random_list_seven)
#     ##user_answer = [input()]
#     ##if user_answer == random_list_seven:
#         ## a+=1 - rounds 2, 3, 4...
#         ##a += 1
#         ##random_list_seven.append(random.randint(0, 10))
#         ##print('it´s your time', random_list_seven)
#         ##user_answer = [input()]
#     ##else:
#         ##print('You lose!')
#         ##a = [1]
#
#     ## so far, the code is running but it´s printing 'you lose' even if the user gives the right answer.

# %% [markdown]
# # 8: let´s try to figure out what´s happening
#
# random_list_seven = []
# a = [1]
# # let´s try to use 'a' to rise one unit each time the user gets right
# #randoms = [range(10)]
# # the idea here is to use 'randoms' to generates ramdom lists within random number from 0 to 10
# for i in range(len(a)):
#     # a=1 in the first round
#     random_list_seven.append(random.randint(0, 10))
#     print('it´s your time', random_list_seven)
#     user_answer = [int(input())]
#     print(user_answer)
#     #a.append(1)
#     print(a)
#     if user_answer == random_list_seven:
#         # a+=1 - rounds 2, 3, 4...
#         #a += [1]
#         a.append(1)
#         #for i in range(len(a)):
#          #   random_list_seven.append(random.randint(0, 10))
#           #  print('it´s your time', random_list_seven)
#            # user_answer = [input()]
#     else:
#         print('You lose!')
#         #a = [1]
#
# print(a)

# %% [markdown]
# # 9: try a while loop
#
# #random_list_eight = []
# #b = [1]
# sequence = [random.randint(0, 9)]
# print(sequence)
# user_answer2 = [int(input())]
# #def user_answer2():
#  #   return [int(input())]
#     #answer2 = [int(input())]
#
# while user_answer2 == sequence:
#     sequence.append(random.randint(0,9)
#     user_answer2 = input()
#   #  print(sequence)
#    # b.append(1)
#     #print(b)
#     #user_answer2()

# %% [markdown]
# # 10: let´s step back and see if we can just create a random list that increases one unit each loop
#
# #c = [1] # c used to increas lenght size but it seems to not be necessary in while loop
# #print('line 4', c)
# simon_says = [int(random.randint(1, 4))]  #generating the list with numb from 1 to 4 to show and ask user´s guess
# print('line 6', simon_says)
# #print('line 7', type(simon_says))
# user_guess = [int(input())]
#
# print(type(simon_says))
# print(type(user_guess))
#
# #def user_guess(): #fuction to input user's guess
#  #   guess = [int(input())]
#   #  return guess
# #user_guess()
# #print(type(user_guess))
# #print(user_guess)
# #for i in range(len(c)):
# while user_guess == simon_says:
#     #c.append(1)
#     #print('line 14', c)
#     simon_says.append(random.randint(1, 4))
#     print('line 22', simon_says)
#     user_guess = [int(input())]
#     #print('line 17', type(user_guess))
#     #print('line 18', test_list9)
#     #print('line 19', c)
# print('saiu do loop')

# %% [markdown]
# # 11: let´s try to begin with empty lists
#
# simon_says = []
# user_guess = []
#
# while simon_says == user_guess:
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     #print(type(simon_says))
#     user_guess.append(int(input()))
#     print(user_guess)
#     #print(type(user_guess))
#
# print('saiu do loop')

# %% [markdown]
# # 11: let get back to for loop
#
# simon_says = [int(random.randint(1, 4))]
# print(simon_says)
# user_guess = [int(input())]
#
# print(simon_says == user_guess)
#
# #for guess in user_guess:
# while user_guess == simon_says:
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     print(type(simon_says))
#     user_guess.append(int(input()))
#     print(user_guess)
#     print(type(user_guess))
#     print(simon_says == user_guess)
#
#
# #elif not user_guess == simon_says:
#  #   print('são diferentes')

# %% [markdown]
# # 11.2: let get back to for loop - adjustements
#
# simon_says = [int(random.randint(1, 4))]
# print(simon_says)
# user_guess = [int(input())]
#
# #print(simon_says == user_guess)
#
# #for guess in user_guess:
#
# while user_guess == simon_says:
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     #print(type(simon_says))
#     user_guess.append(int(input()))
#     print(user_guess)
#     #print(type(user_guess))
#     #print(simon_says == user_guess)
# #elif user_guess != simon_says:
# else:
#     #break
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     #print(type(simon_says))
#     user_guess.append(int(input()))
#     print(user_guess)
#     #print(type(user_guess))
#     #print(simon_says == user_guess)

# %% [markdown]
# # 12: I don´t know what I'm doing anymore
#
# simon_says = [int(random.randint(1, 4))]
# print(simon_says)
# user_guess = [int(input())]
#
# #print(simon_says == user_guess)
#
# #for guess in user_guess:
#
# while user_guess == simon_says:
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     #print(type(simon_says))
#     user_guess.append(int(input()))
#     print(user_guess)
#     #print(type(user_guess))
#     #print(simon_says == user_guess)
#     if not user_guess == simon_says:
#         print('You lose, féra!')
#         simon_says = [int(random.randint(1, 4))]
#         print(simon_says)
#         user_guess = [int(input())]
#         pass
#
# print('saiu do loop')
#
# #elif user_guess != simon_says:
# #else:
#  #   simon_says = []
#   #  user_guess = []
#     #pass
#    # simon_says.append(int(random.randint(1, 4)))
#    # print(simon_says)
#     #print(type(simon_says))
#    # user_guess.append(int(input()))
#     #pass
#     #print(user_guess)
#     #print(type(user_guess))
#     #print(simon_says == user_guess)
# #print('saiu do loop')

# %% [markdown]
# # 13: Almost there! We're back to the game, baby!!
#
# simon_says = [int(random.randint(1, 4))]
# print(simon_says)
# user_guess = [int(input())]
#
# #print(simon_says == user_guess)
#
# while user_guess == simon_says:
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     user_guess.append(int(input()))
#     print(user_guess)
#
#     if not user_guess == simon_says:
#         print('You lose, féra!')
#         print('Try again? y/n')
#         user_choice = (input())
#         if user_choice == 'y':
#             simon_says = [int(random.randint(1, 4))]
#             print(simon_says)
#             user_guess = [int(input())]
#             pass # maybe we should try break
#         elif user_choice == 'n':
#             print('you are not the chosen one')
#
# print('saiu do loop')

# %% [markdown]
# # 14: Trying to fix the loop if user gets wrong at the first round
#
#     ## 13 still works
#
# simon_says = [int(random.randint(1, 4))]
# print(simon_says)
# user_guess = [int(input())]
#
# #print(simon_says == user_guess)
#
# while user_guess == simon_says:  #rembember that it was while loop
#     simon_says.append(int(random.randint(1, 4)))
#     print(simon_says)
#     user_guess.append(int(input()))
#     print(user_guess)
#     #pass
#
# if not user_guess == simon_says:
#     print('You lose, féra!')
#     print('Try again? y/n')
#     user_choice = (input())
#     if user_choice == 'y':
#         simon_says = [int(random.randint(1, 4))]
#         print(simon_says)
#         user_guess = [int(input())]
#         #break
#         while user_guess == simon_says: # there was a if here!
#             print('estamos aqui!')
#             simon_says.append(int(random.randint(1, 4)))
#             print(simon_says)
#             user_guess.append(int(input()))
#             print(user_guess)
#         if not user_guess == simon_says:
#             print('agora estamos aqui')
#
#
# #pass
#
#
#     elif user_choice == 'n':
#         print('you are not the chosen one')
#
# print('saiu do loop')

# %% [markdown]
# # 15: losing the hope
#
#
# for i in range(len(simon_says)):
#     simon_says = [int(random.randint(1, 4))]
#     print(simon_says)
#     user_guess = [int(input())]
#     while user_guess == simon_says:  #rembember that it was while loop:
# #while True:
#         simon_says.append(int(random.randint(1, 4)))
#         print(simon_says)
#         user_guess.append(int(input()))
#         print(user_guess)
#         #pass
#
#     if user_guess != simon_says:
#         print('you lose!')
#         continue
#         print('try againn? y/n')
#         user_choice = input()
#         if user_choice == 'n':
#             print('see ya!')
#             pass
#             #break
#
#         elif user_choice == 'y':
#             simon_says = [int(random.randint(1, 4))]
#             print(simon_says)
#             user_guess = [int(input())]
#
#             while user_guess == simon_says:
#                 simon_says.append(int(random.randint(1, 4)))
#                 print(simon_says)
#                 user_guess.append(int(input()))
#
#             if user_guess != simon_says:
#                 print('estamos aqui')
#                 simon_says = [int(random.randint(1, 4))]
#                 print(simon_says)
#                 user_guess = [int(input())]
#
#         continue
#
#
# #user_guess != simon_says
# ##while user_guess != simon_says:
#     #print('try again? y/n')
#    # user_choice = input()
#     #if user_choice == n:
#        # print('see you soon')
#        # print('end of game')
#     #elif user_choice == y:
#        # break

# %%
# 16: losing the hope 2


simon_says = [int(random.randint(1, 4))]
print(simon_says)
user_guess = [int(input())]
for guess in user_guess:
    
    while user_guess == simon_says:
        simon_says.append(int(random.randint(1, 4)))
        print(simon_says)
        user_guess.append(int(input()))
        print('step 1')
    
    if user_guess != simon_says:
        print('you lose!')
        print('try again? y/n')
        user_choice = input()
        print('step 2')
        
        if user_choice == 'y':
            simon_says = [int(random.randint(1, 4))]
            print(simon_says)
            user_guess = [int(input())]
            print('step 3')
            #continue
        
        elif user_choice == 'n':
            print('see ya next time')
            print('step 4')
# Out:
# [1]
# 1
# [1, 3]
# 2
# step 1
# you lose!
# try again? y/n
# y
# step 2
# [4]
# 3
# step 3
# you lose!
# try again? y/n
# y
# step 2
# [1]
# 2
# step 3

# %% [markdown]
# # DIFICULDADES
#
# 1 - Como gerar uma lista de respostas onde eu não precise inputar só o último número da lista simon_says?
# 2 - Como consertar o loop qdo a primeira resposta está errada?
# 3 - Qual comando usar para sair de um bloco de loop e retornar para o loop principal, ou anterior?
#
#
# # O QUE FALTOU
#
# 1 - invalidar os caractéres que não fossem números de 1 a 4
# 2 - como colocar um timer que oculte a sequência randômica após um certo tempo
